# %%
import os
import time
import random
import numpy as np
import torch 
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import torch.utils.data as data
import torchvision
import torchvision.transforms as transforms
import torchvision.datasets as datasets
from torchsummary import summary
import matplotlib.pyplot as plt
from PIL import Image

# %%
data_path = {
    'train': './data/cassavaleafdata/train',
    'valid':'./data/cassavaleafdata/validation',
    'test':'./data/cassavaleafdata/test'
}

def loader(path):
    return Image.open(path)

img_size = 150
train_transforms = transforms.Compose([
    transforms.Resize((img_size, img_size)),
    transforms.ToTensor(),
])

train_data = datasets.ImageFolder(root=data_path['train'],loader=loader, transform=train_transforms)
valid_data = datasets.ImageFolder(root=data_path['valid'],loader=loader, transform=train_transforms)
test_data = datasets.ImageFolder(root=data_path['test'],loader=loader, transform=train_transforms)

# %%
# Create DataLoaders
BATCH_SIZE = 32

train_dataloader = data.DataLoader(
    train_data,
    shuffle=True,
    batch_size=BATCH_SIZE
)

valid_dataloader = data.DataLoader(
    valid_data,
    batch_size=BATCH_SIZE
)

test_dataloader = data.DataLoader(
    test_data,
    batch_size=BATCH_SIZE
)

print(f'Train batches: {len(train_dataloader)}')
print(f'Valid batches: {len(valid_dataloader)}')
print(f'Test batches: {len(test_dataloader)}')
# Out:
# Train batches: 177
# Valid batches: 60
# Test batches: 59

# %%
class LeNetClassifier(nn.Module):
    def __init__(self, num_classes):
        super().__init__()
        self.conv1 = nn.Conv2d(
            in_channels = 3, out_channels = 6, kernel_size =5, padding='same'
        )
        self.avgpool1 = nn.AvgPool2d(kernel_size=2)
        self.conv2 = nn.Conv2d(in_channels=6,out_channels = 16, kernel_size=5)
        self.avgpool2 = nn.AvgPool2d(kernel_size=2)
        self.flatten = nn.Flatten()
        self.fc_1 = nn.Linear(16 * 35 * 35, 120)
        self.fc_2 = nn.Linear(120,84)
        self.fc_3=nn.Linear(84,num_classes)

    def forward(self,inputs):
        outputs = self.conv1(inputs)
        outputs = self.avgpool1(outputs)
        outputs = F.relu(outputs)
        outputs = self.conv2(outputs)
        outputs = self.avgpool2(outputs)
        outputs = F.relu(outputs)
        outputs = self.flatten(outputs)
        outputs = self.fc_1(outputs)
        outputs = self.fc_2(outputs)
        outputs = self.fc_3(outputs)
        return outputs

# %%
def train(model, optimizer, criterion, train_dataloader, device, epoch=0, log_interval
=50):
    model.train()
    total_acc, total_count = 0, 0
    losses = []
    start_time = time.time()

    for idx, (inputs, labels) in enumerate(train_dataloader):
        inputs = inputs.to(device)
        labels = labels.to(device)

        optimizer.zero_grad()
        predictions = model(inputs)
    # compute loss
        loss = criterion(predictions, labels)
        losses.append(loss.item())
    # backward
        loss.backward()
        torch.nn.utils.clip_grad_norm_(model.parameters(), 0.1)
        optimizer.step()
        total_acc += (predictions.argmax(1) == labels).sum().item()
        total_count += labels.size(0)
        if idx % log_interval == 0 and idx > 0:
            elapsed = time.time()- start_time
            print(
                "| epoch {:3d} | {:5d}/{:5d} batches "
                "| accuracy {:8.3f}".format(
                    epoch, idx, len(train_dataloader), total_acc / total_count
                )
            )
            total_acc, total_count = 0, 0
            start_time = time.time()
        
    epoch_acc = total_acc / total_count
    epoch_loss = sum(losses) / len(losses)
    return epoch_acc, epoch_loss

 # Evaluation function
def evaluate(model, criterion, valid_dataloader):
    model.eval()
    total_acc, total_count = 0, 0
    losses = []

    with torch.no_grad():
        for idx, (inputs, labels) in enumerate(valid_dataloader):
            inputs = inputs.to(device)
            labels = labels.to(device)

            predictions = model(inputs)

            loss = criterion(predictions, labels)
            losses.append(loss.item())

            total_acc += (predictions.argmax(1) == labels).sum().item()
            total_count += labels.size(0)

    epoch_acc = total_acc / total_count
    epoch_loss = sum(losses) / len(losses)
    return epoch_acc, epoch_loss

# %%
num_classes = len(train_data.classes)

device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f'🖥️  Training on: {device}')

if torch.cuda.is_available():
    print(f'GPU Name: {torch.cuda.get_device_name(0)}')
    print(f'GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1e9:.2f} GB')
else:
    print('GPU not available, using CPU')
lenet_model = LeNetClassifier(num_classes)
lenet_model.to(device)

criterion = torch.nn.CrossEntropyLoss()
learning_rate = 2e-4
optimizer = optim.Adam(lenet_model.parameters(),learning_rate)
num_epochs = 10
save_model = './model'
if not os.path.exists(save_model):
    os.makedirs(save_model)
train_accs, train_losses = [], []
eval_accs, eval_losses = [], []
best_loss_eval = 100

for epoch in range(1, num_epochs+1):
    epoch_start_time = time.time()
# Training
    train_acc, train_loss = train(lenet_model, optimizer, criterion, train_dataloader,
device, epoch, log_interval=10)
    train_accs.append(train_acc)
    train_losses.append(train_loss)

# Evaluation
    eval_acc, eval_loss = evaluate(lenet_model, criterion, valid_dataloader)
    eval_accs.append(eval_acc)
    eval_losses.append(eval_loss)

# Save best model
    if eval_loss < best_loss_eval:
        torch.save(lenet_model.state_dict(), save_model + '/lenet_model.pt')

 # Print loss, acc end epoch
    print("-" * 59)
    print(
        "| End of epoch {:3d} | Time: {:5.2f}s | Train Accuracy {:8.3f} | Train Loss{:8.3f} "
        "| Valid Accuracy {:8.3f} | Valid Loss {:8.3f} ".format(epoch, time.time()- epoch_start_time, train_acc, train_loss, eval_acc,eval_loss)
    )
    print("-" * 59)
# Load best model
    lenet_model.load_state_dict(torch.load(save_model + '/lenet_model.pt'))
    lenet_model.eval()
# Out:
# 🖥️  Training on: cpu
# GPU not available, using CPU
# | epoch   1 |    10/  177 batches | accuracy    0.426
# | epoch   1 |    20/  177 batches | accuracy    0.463
# | epoch   1 |    30/  177 batches | accuracy    0.491
# | epoch   1 |    40/  177 batches | accuracy    0.506
# | epoch   1 |    50/  177 batches | accuracy    0.434
# | epoch   1 |    60/  177 batches | accuracy    0.419
# | epoch   1 |    70/  177 batches | accuracy    0.497
# | epoch   1 |    80/  177 batches | accuracy    0.466
# | epoch   1 |    90/  177 batches | accuracy    0.450
# | epoch   1 |   100/  177 batches | accuracy    0.478
# | epoch   1 |   110/  177 batches | accuracy    0.453
# | epoch   1 |   120/  177 batches | accuracy    0.472
# | epoch   1 |   130/  177 batches | accuracy    0.481
# | epoch   1 |   140/  177 batches | accuracy    0.469
# | epoch   1 |   150/  177 batches | accuracy    0.466
# | epoch   1 |   160/  177 batches | accuracy    0.506
# | epoch   1 |   170/  177 batches | accuracy    0.500
# -----------------------------------------------------------
# | End of epoch   1 | Time: 269.08s | Train Accuracy    0.511 | Train Loss   1.332 | Valid Accuracy    0.516 | Valid Loss    1.269
# -----------------------------------------------------------
# | epoch   2 |    10/  177 batches | accuracy    0.574
# | epoch   2 |    20/  177 batches | accuracy    0.531
# | epoch   2 |    30/  177 batches | accuracy    0.484
# | epoch   2 |    40/  177 batches | accuracy    0.487
# | epoch   2 |    50/  177 batches | accuracy    0.550
# | epoch   2 |    60/  177 batches | accuracy    0.566
# | epoch   2 |    70/  177 batches | accuracy    0.494
# | epoch   2 |    80/  177 batches | accuracy    0.491
# | epoch   2 |    90/  177 batches | accuracy    0.581
# | epoch   2 |   100/  177 batches | accuracy    0.584
# | epoch   2 |   110/  177 batches | accuracy    0.537
# | epoch   2 |   120/  177 batches | accuracy    0.500
# | epoch   2 |   130/  177 batches | accuracy    0.600
# | epoch   2 |   140/  177 batches | accuracy    0.547
# | epoch   2 |   150/  177 batches | accuracy    0.519
# | epoch   2 |   160/  177 batches | accuracy    0.494
# | epoch   2 |   170/  177 batches | accuracy    0.569
# -----------------------------------------------------------
# | End of epoch   2 | Time: 86.27s | Train Accuracy    0.565 | Train Loss   1.203 | Valid Accuracy    0.583 | Valid Loss    1.176
# -----------------------------------------------------------
# | epoch   3 |    10/  177 batches | accuracy    0.554
# | epoch   3 |    20/  177 batches | accuracy    0.534
# | epoch   3 |    30/  177 batches | accuracy    0.547
# | epoch   3 |    40/  177 batches | accuracy    0.534
# | epoch   3 |    50/  177 batches | accuracy    0.556
# | epoch   3 |    60/  177 batches | accuracy    0.578
# | epoch   3 |    70/  177 batches | accuracy    0.559
# | epoch   3 |    80/  177 batches | accuracy    0.544
# | epoch   3 |    90/  177 batches | accuracy    0.603
# | epoch   3 |   100/  177 batches | accuracy    0.591
# | epoch   3 |   110/  177 batches | accuracy    0.584
# | epoch   3 |   120/  177 batches | accuracy    0.603
# | epoch   3 |   130/  177 batches | accuracy    0.600
# | epoch   3 |   140/  177 batches | accuracy    0.578
# | epoch   3 |   150/  177 batches | accuracy    0.562
# | epoch   3 |   160/  177 batches | accuracy    0.584
# | epoch   3 |   170/  177 batches | accuracy    0.572
# -----------------------------------------------------------
# | End of epoch   3 | Time: 75.80s | Train Accuracy    0.647 | Train Loss   1.133 | Valid Accuracy    0.575 | Valid Loss    1.169
# -----------------------------------------------------------
# | epoch   4 |    10/  177 batches | accuracy    0.591
# | epoch   4 |    20/  177 batches | accuracy    0.578
# | epoch   4 |    30/  177 batches | accuracy    0.597
# | epoch   4 |    40/  177 batches | accuracy    0.547
# | epoch   4 |    50/  177 batches | accuracy    0.562
# | epoch   4 |    60/  177 batches | accuracy    0.553
# | epoch   4 |    70/  177 batches | accuracy    0.572
# | epoch   4 |    80/  177 batches | accuracy    0.562
# | epoch   4 |    90/  177 batches | accuracy    0.588
# | epoch   4 |   100/  177 batches | accuracy    0.591
# | epoch   4 |   110/  177 batches | accuracy    0.531
# | epoch   4 |   120/  177 batches | accuracy    0.622
# | epoch   4 |   130/  177 batches | accuracy    0.606
# | epoch   4 |   140/  177 batches | accuracy    0.628
# | epoch   4 |   150/  177 batches | accuracy    0.600
# | epoch   4 |   160/  177 batches | accuracy    0.603
# | epoch   4 |   170/  177 batches | accuracy    0.594
# -----------------------------------------------------------
# | End of epoch   4 | Time: 76.17s | Train Accuracy    0.641 | Train Loss   1.082 | Valid Accuracy    0.584 | Valid Loss    1.135
# -----------------------------------------------------------
# | epoch   5 |    10/  177 batches | accuracy    0.642
# | epoch   5 |    20/  177 batches | accuracy    0.581
# | epoch   5 |    30/  177 batches | accuracy    0.550
# | epoch   5 |    40/  177 batches | accuracy    0.600
# | epoch   5 |    50/  177 batches | accuracy    0.594
# | epoch   5 |    60/  177 batches | accuracy    0.597
# | epoch   5 |    70/  177 batches | accuracy    0.566
# | epoch   5 |    80/  177 batches | accuracy    0.597
# | epoch   5 |    90/  177 batches | accuracy    0.631
# | epoch   5 |   100/  177 batches | accuracy    0.609
# | epoch   5 |   110/  177 batches | accuracy    0.578
# | epoch   5 |   120/  177 batches | accuracy    0.591
# | epoch   5 |   130/  177 batches | accuracy    0.662
# | epoch   5 |   140/  177 batches | accuracy    0.619
# | epoch   5 |   150/  177 batches | accuracy    0.622
# | epoch   5 |   160/  177 batches | accuracy    0.641
# | epoch   5 |   170/  177 batches | accuracy    0.653
# -----------------------------------------------------------
# | End of epoch   5 | Time: 84.50s | Train Accuracy    0.565 | Train Loss   1.036 | Valid Accuracy    0.584 | Valid Loss    1.138
# -----------------------------------------------------------
# | epoch   6 |    10/  177 batches | accuracy    0.631
# | epoch   6 |    20/  177 batches | accuracy    0.634
# | epoch   6 |    30/  177 batches | accuracy    0.625
# | epoch   6 |    40/  177 batches | accuracy    0.641
# | epoch   6 |    50/  177 batches | accuracy    0.650
# | epoch   6 |    60/  177 batches | accuracy    0.675
# | epoch   6 |    70/  177 batches | accuracy    0.594
# | epoch   6 |    80/  177 batches | accuracy    0.600
# | epoch   6 |    90/  177 batches | accuracy    0.588
# | epoch   6 |   100/  177 batches | accuracy    0.613
# | epoch   6 |   110/  177 batches | accuracy    0.588
# | epoch   6 |   120/  177 batches | accuracy    0.662
# | epoch   6 |   130/  177 batches | accuracy    0.637
# | epoch   6 |   140/  177 batches | accuracy    0.681
# | epoch   6 |   150/  177 batches | accuracy    0.609
# | epoch   6 |   160/  177 batches | accuracy    0.600
# | epoch   6 |   170/  177 batches | accuracy    0.600
# -----------------------------------------------------------
# | End of epoch   6 | Time: 82.70s | Train Accuracy    0.598 | Train Loss   0.994 | Valid Accuracy    0.591 | Valid Loss    1.119
# -----------------------------------------------------------
# | epoch   7 |    10/  177 batches | accuracy    0.668
# | epoch   7 |    20/  177 batches | accuracy    0.644
# | epoch   7 |    30/  177 batches | accuracy    0.631
# | epoch   7 |    40/  177 batches | accuracy    0.628
# | epoch   7 |    50/  177 batches | accuracy    0.694
# | epoch   7 |    60/  177 batches | accuracy    0.662
# | epoch   7 |    70/  177 batches | accuracy    0.637
# | epoch   7 |    80/  177 batches | accuracy    0.594
# | epoch   7 |    90/  177 batches | accuracy    0.631
# | epoch   7 |   100/  177 batches | accuracy    0.619
# | epoch   7 |   110/  177 batches | accuracy    0.619
# | epoch   7 |   120/  177 batches | accuracy    0.666
# | epoch   7 |   130/  177 batches | accuracy    0.647
# | epoch   7 |   140/  177 batches | accuracy    0.650
# | epoch   7 |   150/  177 batches | accuracy    0.650
# | epoch   7 |   160/  177 batches | accuracy    0.703
# | epoch   7 |   170/  177 batches | accuracy    0.616
# -----------------------------------------------------------
# | End of epoch   7 | Time: 87.87s | Train Accuracy    0.582 | Train Loss   0.937 | Valid Accuracy    0.560 | Valid Loss    1.183
# -----------------------------------------------------------
# | epoch   8 |    10/  177 batches | accuracy    0.608
# | epoch   8 |    20/  177 batches | accuracy    0.641
# | epoch   8 |    30/  177 batches | accuracy    0.678
# | epoch   8 |    40/  177 batches | accuracy    0.644
# | epoch   8 |    50/  177 batches | accuracy    0.644
# | epoch   8 |    60/  177 batches | accuracy    0.706
# | epoch   8 |    70/  177 batches | accuracy    0.688
# | epoch   8 |    80/  177 batches | accuracy    0.653
# | epoch   8 |    90/  177 batches | accuracy    0.656
# | epoch   8 |   100/  177 batches | accuracy    0.691
# | epoch   8 |   110/  177 batches | accuracy    0.656
# | epoch   8 |   120/  177 batches | accuracy    0.675
# | epoch   8 |   130/  177 batches | accuracy    0.675
# | epoch   8 |   140/  177 batches | accuracy    0.641
# | epoch   8 |   150/  177 batches | accuracy    0.647
# | epoch   8 |   160/  177 batches | accuracy    0.681
# | epoch   8 |   170/  177 batches | accuracy    0.659
# -----------------------------------------------------------
# | End of epoch   8 | Time: 205.89s | Train Accuracy    0.636 | Train Loss   0.896 | Valid Accuracy    0.529 | Valid Loss    1.219
# -----------------------------------------------------------
# | epoch   9 |    10/  177 batches | accuracy    0.659
# | epoch   9 |    20/  177 batches | accuracy    0.594
# | epoch   9 |    30/  177 batches | accuracy    0.716
# | epoch   9 |    40/  177 batches | accuracy    0.722
# | epoch   9 |    50/  177 batches | accuracy    0.713
# | epoch   9 |    60/  177 batches | accuracy    0.666
# | epoch   9 |    70/  177 batches | accuracy    0.738
# | epoch   9 |    80/  177 batches | accuracy    0.653
# | epoch   9 |    90/  177 batches | accuracy    0.716
# | epoch   9 |   100/  177 batches | accuracy    0.684
# | epoch   9 |   110/  177 batches | accuracy    0.675
# | epoch   9 |   120/  177 batches | accuracy    0.662
# | epoch   9 |   130/  177 batches | accuracy    0.628
# | epoch   9 |   140/  177 batches | accuracy    0.631
# | epoch   9 |   150/  177 batches | accuracy    0.709
# | epoch   9 |   160/  177 batches | accuracy    0.722
# | epoch   9 |   170/  177 batches | accuracy    0.666
# -----------------------------------------------------------
# | End of epoch   9 | Time: 162.91s | Train Accuracy    0.630 | Train Loss   0.837 | Valid Accuracy    0.581 | Valid Loss    1.168
# -----------------------------------------------------------
# | epoch  10 |    10/  177 batches | accuracy    0.761
# | epoch  10 |    20/  177 batches | accuracy    0.684
# | epoch  10 |    30/  177 batches | accuracy    0.734
# | epoch  10 |    40/  177 batches | accuracy    0.738
# | epoch  10 |    50/  177 batches | accuracy    0.703
# | epoch  10 |    60/  177 batches | accuracy    0.697
# | epoch  10 |    70/  177 batches | accuracy    0.700
# | epoch  10 |    80/  177 batches | accuracy    0.684
# | epoch  10 |    90/  177 batches | accuracy    0.688
# | epoch  10 |   100/  177 batches | accuracy    0.697
# | epoch  10 |   110/  177 batches | accuracy    0.700
# | epoch  10 |   120/  177 batches | accuracy    0.772
# | epoch  10 |   130/  177 batches | accuracy    0.672
# | epoch  10 |   140/  177 batches | accuracy    0.684
# | epoch  10 |   150/  177 batches | accuracy    0.675
# | epoch  10 |   160/  177 batches | accuracy    0.731
# | epoch  10 |   170/  177 batches | accuracy    0.738
# -----------------------------------------------------------
# | End of epoch  10 | Time: 83.65s | Train Accuracy    0.668 | Train Loss   0.771 | Valid Accuracy    0.538 | Valid Loss    1.230
# -----------------------------------------------------------

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(14, 5))

# Plot Accuracy
ax1.plot(range(1, num_epochs + 1), train_accs, label='Training', color='#1f77b4', linewidth=2)
ax1.plot(range(1, num_epochs + 1), eval_accs, label='Evaluation', color='#ff7f0e', linewidth=2)
ax1.set_xlabel('Epochs', fontsize=12)
ax1.set_ylabel('Accuracy', fontsize=12)
ax1.set_title('Model Accuracy', fontsize=14, fontweight='bold')
ax1.legend(loc='lower right')
ax1.grid(True, alpha=0.3)

# Plot Loss
ax2.plot(range(1, num_epochs + 1), train_losses, label='Training', color='#1f77b4', linewidth=2)
ax2.plot(range(1, num_epochs + 1), eval_losses, label='Evaluation', color='#ff7f0e', linewidth=2)
ax2.set_xlabel('Epochs', fontsize=12)
ax2.set_ylabel('Loss', fontsize=12)
ax2.set_title('Model Loss', fontsize=14, fontweight='bold')
ax2.legend(loc='upper right')
ax2.grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

# %%
test_acc, test_loss = evaluate(lenet_model, criterion, test_dataloader)
test_acc, test_loss
# Out:
# (0.5464190981432361, 1.1726146097910606)
