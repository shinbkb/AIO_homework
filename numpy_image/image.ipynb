# %%
import numpy as np
import matplotlib.image as mping
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 import numpy as np
#       2 import matplotlib.image as mping
#
# ModuleNotFoundError: No module named 'numpy'

# %%
img = mping.imread('dog.jpeg')
print(img.shape)
print(img.dtype)
gray_img_01 = (np.max(img, axis =2) + np.min(img, axis =2)) / 2
print(gray_img_01[[0,0]])
# Out:
# (534, 800, 3)
# uint8
# [[102.5  73.5  66.5 ...  28.   28.   28. ]
#  [102.5  73.5  66.5 ...  28.   28.   28. ]]

# %%
gray_img_03 = np.mean(img, axis=2)
print("gray_img_03[[0, 0]] =", gray_img_03[[0, 0]])
# Out:
# gray_img_03[[0, 0]] = [[107.66666667  78.66666667  71.66666667 ... 154.33333333 154.33333333
#   154.33333333]
#  [107.66666667  78.66666667  71.66666667 ... 154.33333333 154.33333333
#   154.33333333]]
